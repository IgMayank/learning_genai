# %% [markdown]
# ### load ENV variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
import sys

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model='gemini-2.5-flash-lite')

# %%
res = llm.invoke("What is GENAI? , explain in 2 lines")

# %%
res.content
# Out:
# 'GENAI, or Generative AI, refers to artificial intelligence models capable of creating new content like text, images, music, and code. It learns patterns from existing data to produce original and novel outputs.'

# %%
print(res.content)
# Out:
# GENAI, or Generative AI, refers to artificial intelligence models capable of creating new content like text, images, music, and code. It learns patterns from existing data to produce original and novel outputs.

# %% [markdown]
# #### promopts are basically of 2 types static and dynamic prompts , lets talk about static prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model='gemini-2.5-flash-lite')

# %%
prompt= [
    ("system","you are a python developer."),
    ("user","what is an array.")
]

chat = llm.invoke(prompt)
print(chat.content)
# here we hve majorly 3 types i.e system,ai,and user , un sytem we tell llm to behave like certain for eg u r python developer , in ai its basically see wether the msg is ai or not ,and in users , the user basically give input ans recives op
# Out:
# In Python, the term "array" can refer to a couple of different things, but the most common and fundamental one is the **list**.
#
# Let's break down what an array generally means and then focus on Python's implementation:
#
# **What is an Array (in a general programming sense)?**
#
# An array is a **data structure** that stores a collection of elements, usually of the **same data type**, in a contiguous block of memory. Key characteristics of a traditional array include:
#
# *   **Ordered:** Elements are stored in a specific order, and each element can be accessed by its **index** (position). Indices typically start from 0.
# *   **Fixed Size (often):** In many programming languages, arrays have a fixed size that is determined when the array is created. You cannot easily add or remove elements beyond its initial capacity.
# ...
