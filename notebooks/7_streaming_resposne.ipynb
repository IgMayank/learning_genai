# %% [markdown]
# ## basically here we use chunks so that it can generate real time data and wht i meant by this is instead of pasting everything at once just paste some small small chunk

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model ="gemini-2.5-flash-lite" ,streaming = True)

# %%
question = "what are prompts"

# %%
res = llm.stream(question)
for chunk in res:
    print(chunk.content,end="")
# Out:
# In the context of Artificial Intelligence (AI), especially with large language models (LLMs) like me, **prompts** are essentially **instructions, questions, or any form of input you provide to the AI to guide its response.**
#
# Think of it like this:
#
# *   **You are the director, and the AI is the actor.** The prompt is your script, telling the actor what to say, what to do, or what emotion to convey.
# *   **You are the user, and the AI is the tool.** The prompt is how you operate the tool to get the desired output.
#
# **Key Characteristics of Prompts:**
#
# *   **They initiate interaction:** A prompt is the starting point of a conversation or task with an AI.
# *   **They provide context:** Prompts often include information that helps the AI understand the situation, the desired tone, or the specific requirements.
# ...
